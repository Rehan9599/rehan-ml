# %% [markdown]
# # Module: Logging Assignments
# ## Lesson: Logging
# ### Assignment 1: Basic Logging
#
# 1. Write a Python function to create a basic logger that logs messages to a file named `app.log`.
# 2. Modify the function to log messages of levels: DEBUG, INFO, WARNING, ERROR, and CRITICAL.
#
# ### Assignment 2: Logging with Different Handlers
#
# 1. Write a Python function to create a logger that logs messages to both a file named `app.log` and the console.
# 2. Modify the function to use different logging levels for the file and console handlers.
#
# ### Assignment 3: Formatting Log Messages
#
# 1. Write a Python function to create a logger with a custom log message format that includes the timestamp, logging level, and message.
# 2. Modify the function to use different formats for the file and console handlers.
#
# ### Assignment 4: Rotating Log Files
#
# 1. Write a Python function to create a logger that uses a rotating file handler, which creates a new log file when the current log file reaches a certain size.
# 2. Modify the function to keep a specified number of backup log files.
#
# ### Assignment 5: Logging Exceptions
#
# 1. Write a Python function that logs an exception stack trace to a log file when an exception occurs.
# 2. Modify the function to log the stack trace at the ERROR level.
#
# ### Assignment 6: Contextual Logging
#
# 1. Write a Python function to create a logger that includes contextual information (e.g., function name, line number) in the log messages.
# 2. Modify the function to include additional contextual information (e.g., user ID, session ID).
#
# ### Assignment 7: Configuring Logging with a Dictionary
#
# 1. Write a Python function to configure logging using a dictionary. The configuration should include handlers for both file and console logging.
# 2. Modify the dictionary to include different logging levels and formats for each handler.
#
# ### Assignment 8: Logging in a Multi-Module Application
#
# 1. Write a Python script that sets up logging for a multi-module application. Each module should have its own logger.
# 2. Modify the script to propagate log messages from each module's logger to a root logger that handles logging to a file.
#
# ### Assignment 9: Logging Performance
#
# 1. Write a Python script to benchmark the performance of logging with different handlers (e.g., file handler, console handler, rotating file handler).
# 2. Modify the script to compare the performance of logging with and without message formatting.
#
# ### Assignment 10: Advanced Logging Configuration
#
# 1. Write a Python function to configure logging using an external configuration file (e.g., `logging.conf`). The configuration should include handlers for file and console logging.
# 2. Modify the configuration file to use different logging levels and formats for each handler.

# %%
import logging

logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s -%(name)s- %(levelname)s -%(message)s',
    datefmt='%Y-%m-%d %H:%M:%S',
    handlers=[
        logging.FileHandler("app.log"),
        logging.StreamHandler()
    ]
)

logging.debug("this is a debug msg")
logging.error("this is an error")
# Out:
# 2026-08-14 10:16:34 -root- DEBUG -this is a debug msg
# 2026-08-14 10:16:34 -root- ERROR -this is an error

# %%
from logging.handlers import RotatingFileHandler

def logger_with_rotating_file_handler():
    logger = logging.getLogger('rotating_logger')
    logger.setLevel(logging.DEBUG)
    
    rotating_handler = RotatingFileHandler('rotating_app.log', maxBytes=2000, backupCount=5)
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    rotating_handler.setFormatter(formatter)
    
    logger.addHandler(rotating_handler)
    
    for i in range(100):
        logger.debug('This is debug message number {}'.format(i))

# Test the function
logger_with_rotating_file_handler()
# Out:
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 0
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 1
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 2
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 3
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 4
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 5
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 6
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 7
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 8
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 9
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 10
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 11
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 12
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 13
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 14
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 15
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 16
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 17
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 18
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 19
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 20
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 21
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 22
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 23
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 24
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 25
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 26
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 27
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 28
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 29
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 30
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 31
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 32
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 33
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 34
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 35
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 36
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 37
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 38
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 39
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 40
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 41
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 42
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 43
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 44
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 45
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 46
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 47
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 48
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 49
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 50
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 51
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 52
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 53
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 54
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 55
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 56
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 57
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 58
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 59
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 60
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 61
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 62
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 63
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 64
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 65
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 66
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 67
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 68
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 69
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 70
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 71
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 72
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 73
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 74
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 75
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 76
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 77
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 78
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 79
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 80
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 81
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 82
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 83
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 84
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 85
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 86
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 87
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 88
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 89
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 90
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 91
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 92
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 93
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 94
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 95
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 96
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 97
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 98
# 2026-08-14 10:18:49 -rotating_logger- DEBUG -This is debug message number 99
